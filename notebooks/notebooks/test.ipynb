# %%
import numpy as np
import pandas as pd
import sklearn
import xgboost as xgb

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
print("XGBoost:", xgb.__version__)
print("\n✅ AgroInsight Kenya environment is ready!")
# Out:
# NumPy: 2.4.3
# Pandas: 2.3.3
# Scikit-learn: 1.8.0
# XGBoost: 3.2.0
#
# ✅ AgroInsight Kenya environment is ready!
